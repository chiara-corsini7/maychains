# %% [markdown]
# # Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt

import gsd, gsd.hoomd

# %%
# Load trajectory data
trajectory = gsd.hoomd.open('traj.gsd')

print(f"Trajectory contains {len(trajectory)} frames")

# %% [markdown]
# # End-to-end distance

# %% [markdown]
# # Radius of gyration

# %% [markdown]
# # Monomer mean squared displacement
